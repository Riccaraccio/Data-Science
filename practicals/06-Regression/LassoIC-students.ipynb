# %% [markdown]
# # Lasso Regression with Information Criteria
#
# This notebook performs Lasso regression on the diabetes dataset to demonstrate feature selection via information criteria:
# 1. Loading the diabetes dataset and adding random features
# 2. Standardizing the features for optimal performance
# 3. Training Lasso models with varying regularization strengths
# 4. Evaluating models using AIC and BIC information criteria
# 5. Visualizing the impact of the alpha parameter on model selection

# %% [markdown]
# ## Imports

# %%
import numpy as np
# import ...

# %% [markdown]
# ## Load and Prepare Data

# %%
# Load diabetes dataset from sklearn
# X, y = ...

rng = np.random.RandomState(42)
n_random_features = 14
# Generate random features
# X_random = ...

# Concatenate random features with original features
# X = ...  # Shape should be: (442, 14 + 14)

# Standardize features for optimal performance
# ...

# %% [markdown]
# ## Information Criteria Functions
#
# Implement AIC and BIC. Both take the true labels, predictions, and number of model parameters `k`. Both use the formula:
# $$\text{IC} = n \ln\!\left(\frac{\text{RSS}}{n}\right) + \text{penalty}(k)$$

# %%
def AIC(y_true, y_pred, k):
    """
    Parameters
    ----------
    y_true : array-like — actual target values
    y_pred : array-like — predicted target values
    k      : int        — number of model parameters

    Returns AIC score (lower is better)
    """
    # ...
    return aic

def BIC(y_true, y_pred, k):
    """
    Parameters
    ----------
    y_true : array-like — actual target values
    y_pred : array-like — predicted target values
    k      : int        — number of model parameters

    Returns BIC score (lower is better)
    """
    # ...
    return bic

# %% [markdown]
# ## Train Models Across Alpha Values
#
# Sweep `alpha` from $10^{-2}$ to $10^{2}$ (log-spaced, 100 values). For each alpha, fit a Lasso model and compute both information criteria.
#
# **Hint:** [`sklearn.linear_model.Lasso`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html)

# %%
scores_aic = []
scores_bic = []

# logspace for alpha values from 10^-2 to 10^2
# alphas = ...

# for alpha in alphas:
    # Initialize Lasso model with current alpha and random_state=42
    # model = ...

    # Fit the model
    # ...

    # Predict
    # y_pred = ...

    # Count non-zero coefficients + intercept
    # k = ...

    # Append AIC and BIC scores
    # ...

# %% [markdown]
# ## Visualize Information Criteria
#
# Plot AIC, BIC, and their geometric mean against alpha on a log scale.

# %%
# Plot AIC and BIC scores against alpha values
# plt. ...

# Add logarithmic scale to x-axis
# plt. ...

# Add labels, title, legend, grid, and show the plot
# ...
