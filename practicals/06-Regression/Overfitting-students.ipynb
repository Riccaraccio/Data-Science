# %% [markdown]
# # Polynomial Regression and Overfitting
#
# This notebook demonstrates overfitting in polynomial regression and how Lasso regularization helps:
# 1. Generating synthetic quadratic data with controlled noise
# 2. Splitting data into training and test sets
# 3. Fitting polynomial models of increasing complexity (degrees 1–14)
# 4. Comparing standard Linear Regression vs Lasso regularization
# 5. Analyzing overfitting through training and testing error visualization

# %% [markdown]
# ## Imports

# %%
import numpy as np
# import ...

# %% [markdown]
# ## Generate Synthetic Data
#
# Create `x` from 0 to 10 (40 points), compute the true quadratic relationship $y = 2 + 3x - 0.5x^2$, add Gaussian noise (`noise_level=5`), then split 70/30 into train/test.

# %%
np.random.seed(42)

# Create x vector from 0 to 10
# x = ...

# True relationship: y = 2 + 3x - 0.5x^2
# y_true = ...

noise_level = 5
# Add Gaussian noise
# y_noisy = y_true + ...

# Split data (test_size=0.3, random_state=42)
# X_train, X_test, y_train, y_test = train_test_split(...)

# %% [markdown]
# ## Visualize the Data

# %%
# plt.scatter(X_train, y_train, label='Training Data')
# plt.scatter(X_test, y_test, label='Testing Data', color='orange')
# plt.plot(x, y_true, label='True Relationship', color='red')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('Data Visualization')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Fit Polynomial Models of Increasing Degree
#
# For degrees 1–14, create Vandermonde polynomial features and fit a `LinearRegression` model. Record training and test MSE for each degree.
#
# **Hint:** [`numpy.vander`](https://numpy.org/doc/stable/reference/generated/numpy.vander.html) with `increasing=True`.
# **Hint:** [`sklearn.linear_model.LinearRegression`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %%
degrees = range(1, 15)

linear_train_errors = []
linear_test_errors  = []

# for degree in degrees:
    # Create polynomial features using Vandermonde matrix
    # X_train_poly = ...
    # X_test_poly  = ...

    # Fit LinearRegression
    # model = ...
    # ...

    # Predict
    # y_train_pred = ...
    # y_test_pred  = ...

    # Append MSE to the lists
    # ...

# %% [markdown]
# ## Visualize Fitted Curves and Training vs Testing Error
#
# Plot training and test errors against polynomial degree. Use a log scale on the y-axis to better see the overfitting behaviour.

# %%
# Plot degrees vs training and test errors
# use logarithmic scale on y-axis
# ...
