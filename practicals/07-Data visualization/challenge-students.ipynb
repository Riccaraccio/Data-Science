# %% [markdown]
# # Mini Data Visualization Challenge
#
# ## The scenario
#
# You have been given data from a reactor study. Two catalysts (**A** and **B**) were tested at different temperatures (300–600 K), pressures (1 and 5 bar), and residence times (30, 60, 120 s).
#
# Three variables were measured:
# - **Conversion** — fraction of reactant converted (0–1)
# - **Selectivity** — fraction of converted reactant going to the desired product (0–1)
# - **Residence time** — time the reactant spends in the reactor (s)
#
# A colleague needs to understand what this data says **at a glance**. Your job is to produce **three plots** that together tell a clear, honest story.
#
# ---
#
# ## Rules
#
# 1. **No default matplotlib styling** — make at least one deliberate aesthetic choice (colors, grid style, figure size, font size…)
# 2. Every plot must have: **axis labels with units**, a **descriptive title**, and a **legend** if more than one series is shown
# 3. For each plot, write **one sentence** justifying your chart type choice
# 4. Think about what story each plot tells — don't just plot everything against everything
#
# ---
#
# ## Suggested questions to explore (pick three)
#
# - How does conversion change with temperature? Does pressure matter?
# - Is there a conversion–selectivity trade-off? Does it depend on catalyst or pressure?
# - How does residence time affect conversion? Is the effect the same at all temperatures?
# - Which catalyst would you recommend, and under what conditions?

# %%
# --- Setup ---
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('reactor_data.csv')
print(df.shape)
df.head()

# %%
# Quick summary — useful to run before plotting
print(df.describe())
print('\nCatalysts:', df['Catalyst'].unique())
print('Pressures (bar):', df['Pressure_bar'].unique())
print('Residence times (s):', df['Residence_time_s'].unique())

# %% [markdown]
# ---
# ## Plot 1
#
# **Question I'm answering:** *(write here)*
#
# **Why this chart type?** *(one sentence)*

# %%
# Plot 1
fig, ax = plt.subplots(figsize=(7, 4))

# Your code here

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Plot 2
#
# **Question I'm answering:** *(write here)*
#
# **Why this chart type?** *(one sentence)*

# %%
# Plot 2
fig, ax = plt.subplots(figsize=(7, 4))

# Your code here

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Plot 3
#
# **Question I'm answering:** *(write here)*
#
# **Why this chart type?** *(one sentence)*

# %%
# Plot 3
fig, ax = plt.subplots(figsize=(7, 4))

# Your code here

plt.tight_layout()
plt.show()
